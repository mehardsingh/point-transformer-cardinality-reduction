# %%
import os 
if "notebooks" == os.path.abspath('.')[-9:]: os.chdir("..")

import pandas as pd
import matplotlib.pyplot as plt

# %%
progress = pd.read_csv("outputs/point_transformer/progress.csv")[:160]
accs = list(progress["T_Accuracy"][140:])
print(sum(accs) / len(accs))
# Out:
# 0.65390625

# %%
progress = pd.read_csv("outputs/pt_merged/progress.csv") 
accs = list(progress["T_Accuracy"][140:])
print(sum(accs) / len(accs))
# Out:
# 0.6102430555555556

# %%
progress = pd.read_csv("outputs/point_transformer/progress.csv")
# progress = pd.read_csv("outputs/pt_merged/progress.csv") 
progress
# Out:
#      step    T_Loss  T_Accuracy  T_Precision  T_Recall      T_F1  V_Loss  \
# 0       0  3.841454    0.031250     0.019481  0.020202  0.018182     NaN
# 1       1  3.716125    0.015625     0.014706  0.005882  0.008403     NaN
# 2       2  3.610515    0.109375     0.051158  0.096847  0.060811     NaN
# 3       3  3.507980    0.046875     0.025253  0.016450  0.017753     NaN
# 4       4  3.521325    0.125000     0.078495  0.101882  0.070200     NaN
# ..    ...       ...         ...          ...       ...       ...     ...
# 817   817  0.583680    0.843750     0.780460  0.813793  0.776628     NaN
# 818   818  1.059574    0.666667     0.500000  0.500000  0.500000     NaN
# 819   819  0.953549    0.671875     0.462356  0.453831  0.425922     NaN
# 820   820  0.823343    0.734375     0.660256  0.634615  0.616117     NaN
# 821   821  0.822747    0.781250     0.687356  0.663793  0.656909     NaN
#
#      V_Accuracy  V_Precision  V_Recall  V_F1
# 0           NaN          NaN       NaN   NaN
# 1           NaN          NaN       NaN   NaN
# 2           NaN          NaN       NaN   NaN
# 3           NaN          NaN       NaN   NaN
# 4           NaN          NaN       NaN   NaN
# ..          ...          ...       ...   ...
# 817         NaN          NaN       NaN   NaN
# 818         NaN          NaN       NaN   NaN
# 819         NaN          NaN       NaN   NaN
# 820         NaN          NaN       NaN   NaN
# 821         NaN          NaN       NaN   NaN
#
# [822 rows x 11 columns]

# %%
train_steps = list(progress["step"])
train_loss = list(progress["T_Loss"])
train_acc = list(progress["T_Accuracy"])
train_f1 = list(progress["T_Precision"])
train_f1 = list(progress["T_Recall"])

# %%
val_steps = list(progress[progress['V_Loss'].notna()]['step'])
val_loss = list(progress["V_Loss"][val_steps])
val_acc = list(progress["V_Accuracy"][val_steps])
val_f1 = list(progress["V_Precision"][val_steps])
val_f1 = list(progress["V_Recall"][val_steps])

print(val_acc)
# Out:
# [0.5048426150121066, 0.6029055690072639, 0.5871670702179177, 0.7506053268765133, 0.7360774818401937, 0.7953995157384988, 0.8026634382566586, 0.8232445520581114]

# %%
plt.plot(train_steps, train_loss, label='Training Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(val_steps, val_loss, label='Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(train_steps, train_acc, label='Acc')
# plt.plot(val_steps, val_acc, label='Validation Acc')
plt.xlabel('Steps')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(train_steps, train_f1, label='Training F1')
plt.plot(val_steps, val_f1, label='Validation F1')
plt.xlabel('Steps')
plt.ylabel('F1')
plt.legend()
plt.show()
