# %%
import os 
if "notebooks" == os.path.abspath('.')[-9:]: os.chdir("..")

import pandas as pd
import matplotlib.pyplot as plt

# %%
progress = pd.read_csv("outputs/pt_normal/progress.csv")
# accs = list(progress["T_Accuracy"][140:])
# print(sum(accs) / len(accs))

# %%
# progress = pd.read_csv("outputs/pt_merged/progress.csv")

# %%
# progress = pd.read_csv("outputs/point_transformer/progress.csv")
# progress = pd.read_csv("outputs/pt_merged/progress.csv") 
progress
# Out:
#    step    T_Loss  T_Accuracy  T_Precision  T_Recall      T_F1    V_Loss  \
# 0    77  1.647606    0.382603     0.199174  0.295778  0.213667  0.050759
# 1   153  1.672472    0.366885     0.194742  0.284433  0.202986  0.054013
# 2   229  1.632915    0.350119     0.174769  0.266707  0.186773  0.033525
#
#    V_Accuracy  V_Precision  V_Recall      V_F1
# 0       0.232      0.16653     0.232  0.133558
# 1       0.100      0.01000     0.100  0.018182
# 2       0.150      0.17901     0.150  0.086645

# %%
train_steps = list(progress["step"])
train_loss = list(progress["T_Loss"])
train_acc = list(progress["T_Accuracy"])
train_f1 = list(progress["T_Precision"])
train_f1 = list(progress["T_Recall"])

# %%
# val_steps = list(progress[progress['V_Loss'].notna()]['step'])
val_loss = list(progress["V_Loss"])
val_acc = list(progress["V_Accuracy"])
val_f1 = list(progress["V_Precision"])
val_f1 = list(progress["V_Recall"])

print(val_acc)
# Out:
# [0.232, 0.1, 0.15]

# %%
plt.plot(train_steps, train_loss, label='Training Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(train_steps, val_loss, label='Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(train_steps, train_acc, label='Acc')
plt.plot(train_steps, val_acc, label='Validation Acc')
plt.xlabel('Steps')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(train_steps, train_f1, label='Training F1')
plt.plot(train_steps, val_f1, label='Validation F1')
plt.xlabel('Steps')
plt.ylabel('F1')
plt.legend()
plt.show()
