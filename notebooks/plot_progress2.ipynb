# %%
import os 
if "notebooks" == os.path.abspath('.')[-9:]: os.chdir("..")

import pandas as pd
import matplotlib.pyplot as plt

# %%
# progress = pd.read_csv("outputs/point_transformer/progress.csv")[:158]
progress = pd.read_csv("outputs/pt_merged/progress.csv") 
progress
# Out:
#      step    T_Loss  T_Accuracy  T_Precision  T_Recall      T_F1  V_Loss  \
# 0       0  3.941350    0.000000     0.000000  0.000000  0.000000     NaN
# 1       1  3.652172    0.078125     0.028108  0.033333  0.029261     NaN
# 2       2  3.665831    0.046875     0.070707  0.051515  0.058081     NaN
# 3       3  3.507654    0.171875     0.075878  0.118182  0.086800     NaN
# 4       4  3.541719    0.109375     0.038776  0.042857  0.037143     NaN
# ..    ...       ...         ...          ...       ...       ...     ...
# 153   153  1.417881    0.593750     0.378434  0.450458  0.380200     NaN
# 154   154  1.439233    0.562500     0.439815  0.523986  0.458901     NaN
# 155   155  1.429613    0.562500     0.373597  0.379762  0.362532     NaN
# 156   156  1.319068    0.671875     0.465517  0.474548  0.454209     NaN
# 157   157  1.334172    0.640625     0.502366  0.486332  0.477392     NaN
#
#      V_Accuracy  V_Precision  V_Recall  V_F1
# 0           NaN          NaN       NaN   NaN
# 1           NaN          NaN       NaN   NaN
# 2           NaN          NaN       NaN   NaN
# 3           NaN          NaN       NaN   NaN
# 4           NaN          NaN       NaN   NaN
# ..          ...          ...       ...   ...
# 153         NaN          NaN       NaN   NaN
# 154         NaN          NaN       NaN   NaN
# 155         NaN          NaN       NaN   NaN
# 156         NaN          NaN       NaN   NaN
# 157         NaN          NaN       NaN   NaN
#
# [158 rows x 11 columns]

# %%
train_steps = list(progress["step"])
train_loss = list(progress["T_Loss"])
train_acc = list(progress["T_Accuracy"])
train_f1 = list(progress["T_Precision"])
train_f1 = list(progress["T_Recall"])

# %%
val_steps = list(progress[progress['V_Loss'].notna()]['step'])
val_loss = list(progress["V_Loss"][val_steps])
val_acc = list(progress["V_Accuracy"][val_steps])
val_f1 = list(progress["V_Precision"][val_steps])
val_f1 = list(progress["V_Recall"][val_steps])

print(val_acc)
# Out:
# [0.5338983050847458]

# %%
plt.plot(train_steps, train_loss, label='Training Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(val_steps, val_loss, label='Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(train_steps, train_acc, label='Acc')
# plt.plot(val_steps, val_acc, label='Validation Acc')
plt.xlabel('Steps')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(train_steps, train_f1, label='Training F1')
plt.plot(val_steps, val_f1, label='Validation F1')
plt.xlabel('Steps')
plt.ylabel('F1')
plt.legend()
plt.show()
