# %%
import os 
if "notebooks" == os.path.abspath('.')[-9:]: os.chdir("..")

import pandas as pd
import matplotlib.pyplot as plt

# %%
progress = pd.read_csv("outputs/pointnet/progress.csv")
progress
# Out:
#     step    T_Loss  T_Accuracy  T_Precision  T_Recall      T_F1  V_Loss  \
# 0      0  3.915366    0.031250     0.017921  0.026882  0.016129     NaN
# 1      1  3.824233    0.000000     0.000000  0.000000  0.000000     NaN
# 2      2  3.743284    0.062500     0.030729  0.020387  0.024306     NaN
# 3      3  3.655270    0.109375     0.067778  0.079167  0.066473     NaN
# 4      4  3.651623    0.156250     0.047740  0.102564  0.062088     NaN
# ..   ...       ...         ...          ...       ...       ...     ...
# 66    66  2.280262    0.421875     0.163286  0.258025  0.193461     NaN
# 67    67  2.166276    0.406250     0.185821  0.289377  0.208295     NaN
# 68    68  1.999532    0.421875     0.168483  0.205357  0.172848     NaN
# 69    69  2.145168    0.437500     0.198522  0.284072  0.225631     NaN
# 70    70  2.434084    0.328125     0.167989  0.237654  0.182977     NaN
#
#     V_Accuracy  V_Precision  V_Recall  V_F1
# 0          NaN          NaN       NaN   NaN
# 1          NaN          NaN       NaN   NaN
# 2          NaN          NaN       NaN   NaN
# 3          NaN          NaN       NaN   NaN
# 4          NaN          NaN       NaN   NaN
# ..         ...          ...       ...   ...
# 66         NaN          NaN       NaN   NaN
# 67         NaN          NaN       NaN   NaN
# 68         NaN          NaN       NaN   NaN
# 69         NaN          NaN       NaN   NaN
# 70         NaN          NaN       NaN   NaN
#
# [71 rows x 11 columns]

# %%
train_steps = list(progress["step"])
train_loss = list(progress["T_Loss"])
train_acc = list(progress["T_Accuracy"])
train_f1 = list(progress["T_Precision"])
train_f1 = list(progress["T_Recall"])

# %%
val_steps = list(progress[progress['V_Loss'].notna()]['step'])
val_loss = list(progress["V_Loss"][val_steps])
val_acc = list(progress["V_Accuracy"][val_steps])
val_f1 = list(progress["V_Precision"][val_steps])
val_f1 = list(progress["V_Recall"][val_steps])

# %%
plt.plot(train_steps, train_loss, label='Training Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(val_steps, val_loss, label='Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(train_steps, train_acc, label='Training Acc')
plt.plot(val_steps, val_acc, label='Validation Acc')
plt.xlabel('Steps')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(train_steps, train_f1, label='Training F1')
plt.plot(val_steps, val_f1, label='Validation F1')
plt.xlabel('Steps')
plt.ylabel('F1')
plt.legend()
plt.show()
